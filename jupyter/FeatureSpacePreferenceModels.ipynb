# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ood_df = pd.read_csv('/users/lucelo/UQLRM/uqlrm/scripts/slurm/metadata_llama_rw_infer_v0_.tsv', sep='\t', header=0)

# %%
ood_df.head()
# Out:
#   Preference  RewardScore               Model Dataset     id
# 0     chosen     1.046875  llama_rw_infer_v0_   train   1801
# 1     chosen     2.890625  llama_rw_infer_v0_   train  87053
# 2     chosen    -0.628906  llama_rw_infer_v0_   train  59149
# 3     chosen     1.750000  llama_rw_infer_v0_   train  20080
# 4     chosen     2.218750  llama_rw_infer_v0_   train  72323

# %%
ood_df['RewardScore'].hist(bins=100)
# Out:
# <Axes: >

# %%
ood_df[ood_df['Preference'] == 'chosen']['RewardScore'].hist(bins=100, alpha=0.5, label='chosen')
ood_df[ood_df['Preference'] == 'rejected']['RewardScore'].hist(bins=100, alpha=0.5, label='rejected')
plt.legend()
plt.title("Chosen/Rejected - Llama2")
# Out:
# Text(0.5, 1.0, 'Chosen/Rejected - Llama2')

# %%
ood_df[ood_df['Dataset'] == 'train']['RewardScore'].hist(bins=100, alpha=0.5, label='train')
ood_df[ood_df['Dataset'] == 'ood']['RewardScore'].hist(bins=100, alpha=0.5, label='ood')
ood_df[ood_df['Dataset'] == 'shuffled']['RewardScore'].hist(bins=100, alpha=0.5, label='shuffled')
plt.legend()
plt.title("Reward Scores - Llama7B")
# Out:
# Text(0.5, 1.0, 'Reward Scores - Llama7B')

# %%
ood_df = pd.read_csv('/users/lucelo/UQLRM/metadata_gpt2-after-reward-modeling.tsv', sep='\t', header=0)

# %%
ood_df.head()
# Out:
#   Preference  RewardScore                       Model Dataset     id
# 0     chosen     0.071289  gpt2-after-reward-modeling   train   1801
# 1     chosen     0.554688  gpt2-after-reward-modeling   train  87053
# 2     chosen    -0.451172  gpt2-after-reward-modeling   train  59149
# 3     chosen     0.406250  gpt2-after-reward-modeling   train  20080
# 4     chosen    -0.451172  gpt2-after-reward-modeling   train  72323

# %%
ood_df['RewardScore'].hist(bins=100)
# Out:
# <Axes: >

# %%
ood_df[ood_df['Preference'] == 'chosen']['RewardScore'].hist(bins=100, alpha=0.5, label='chosen')
ood_df[ood_df['Preference'] == 'rejected']['RewardScore'].hist(bins=100, alpha=0.5, label='rejected')
plt.legend()
plt.title("Chosen/Rejected - GPT2")
# Out:
# Text(0.5, 1.0, 'Chosen/Rejected - GPT2')

# %%
ood_df[ood_df['Dataset'] == 'train']['RewardScore'].hist(bins=100, alpha=0.5, label='train')
ood_df[ood_df['Dataset'] == 'ood']['RewardScore'].hist(bins=100, alpha=0.5, label='ood')
ood_df[ood_df['Dataset'] == 'shuffled']['RewardScore'].hist(bins=100, alpha=0.5, label='shuffled')
plt.legend()
plt.title("Reward Scores - GPT2")
# Out:
# Text(0.5, 1.0, 'Reward Scores - GPT2')

# %%
ood_df = pd.read_csv('/users/lucelo/UQLRM/uqlrm/scripts/slurm/metadata_hermes_infer_.tsv', sep='\t', header=0)

# %%
ood_df.head()
# Out:
#   Preference  RewardScore          Model Dataset     id
# 0     chosen    -0.535156  hermes_infer_   train   1801
# 1     chosen     2.671875  hermes_infer_   train  87053
# 2     chosen     1.015625  hermes_infer_   train  59149
# 3     chosen     1.656250  hermes_infer_   train  20080
# 4     chosen     1.609375  hermes_infer_   train  72323

# %%
ood_df['RewardScore'].hist(bins=100)
# Out:
# <Axes: >

# %%
ood_df[ood_df['Preference'] == 'chosen']['RewardScore'].hist(bins=100, alpha=0.5, label='chosen')
ood_df[ood_df['Preference'] == 'rejected']['RewardScore'].hist(bins=100, alpha=0.5, label='rejected')
plt.legend()
plt.title("Chosen/Rejected - Hermes")
# Out:
# Text(0.5, 1.0, 'Chosen/Rejected - Hermes')

# %%
ood_df[ood_df['Dataset'] == 'train']['RewardScore'].hist(bins=100, alpha=0.5, label='train')
ood_df[ood_df['Dataset'] == 'ood']['RewardScore'].hist(bins=100, alpha=0.5, label='ood')
ood_df[ood_df['Dataset'] == 'shuffled']['RewardScore'].hist(bins=100, alpha=0.5, label='shuffled')
plt.legend()
plt.title("Reward Scores - Hermes")
# Out:
# Text(0.5, 1.0, 'Reward Scores - Hermes')

# %%
ood_df = pd.read_csv('/users/lucelo/UQLRM/uqlrm/scripts/slurm/metadata_gpt2xl-infer_.tsv', sep='\t', header=0)

# %%
ood_df.head()
# Out:
#   Preference  RewardScore          Model Dataset     id
# 0     chosen     2.375000  gpt2xl-infer_   train   1801
# 1     chosen     1.539062  gpt2xl-infer_   train  87053
# 2     chosen     1.953125  gpt2xl-infer_   train  59149
# 3     chosen     1.515625  gpt2xl-infer_   train  20080
# 4     chosen     0.960938  gpt2xl-infer_   train  72323

# %%
ood_df['RewardScore'].hist(bins=100)
# Out:
# <Axes: >

# %%
ood_df[ood_df['Preference'] == 'chosen']['RewardScore'].hist(bins=100, alpha=0.5, label='chosen')
ood_df[ood_df['Preference'] == 'rejected']['RewardScore'].hist(bins=100, alpha=0.5, label='rejected')
plt.legend()
plt.title("Chosen/Rejected - GPT2-XL")
# Out:
# Text(0.5, 1.0, 'Chosen/Rejected - GPT2-XL')

# %%
ood_df[ood_df['Dataset'] == 'train']['RewardScore'].hist(bins=100, alpha=0.5, label='train')
ood_df[ood_df['Dataset'] == 'ood']['RewardScore'].hist(bins=100, alpha=0.5, label='ood')
ood_df[ood_df['Dataset'] == 'shuffled']['RewardScore'].hist(bins=100, alpha=0.5, label='shuffled')
plt.legend()
plt.title("Reward Scores - GPT2-XL")
# Out:
# Text(0.5, 1.0, 'Reward Scores - GPT2-XL')

# %%
ood_df = pd.read_csv('/users/lucelo/UQLRM/metadata_single_mlp.tsv', sep='\t', header=0)

# %%
ood_df.head()
# Out:
#   Preference  RewardScore       Model Dataset     id
# 0     chosen    -1.368726  single_mlp   train   1801
# 1     chosen     1.213971  single_mlp   train  87053
# 2     chosen    -0.127177  single_mlp   train  59149
# 3     chosen     1.100560  single_mlp   train  20080
# 4     chosen     0.452748  single_mlp   train  72323

# %%
ood_df['RewardScore'].hist(bins=100)
# Out:
# <Axes: >

# %%
ood_df[ood_df['Preference'] == 'chosen']['RewardScore'].hist(bins=100, alpha=0.5, label='chosen')
ood_df[ood_df['Preference'] == 'rejected']['RewardScore'].hist(bins=100, alpha=0.5, label='rejected')
plt.legend()
plt.title("Chosen/Rejected - MLP")
# Out:
# Text(0.5, 1.0, 'Chosen/Rejected - MLP')

# %%
ood_df[ood_df['Dataset'] == 'train']['RewardScore'].hist(bins=100, alpha=0.5, label='train')
ood_df[ood_df['Dataset'] == 'ood']['RewardScore'].hist(bins=100, alpha=0.5, label='ood')
ood_df[ood_df['Dataset'] == 'shuffled']['RewardScore'].hist(bins=100, alpha=0.5, label='shuffled')
plt.legend()
plt.title("Reward Scores - MLP")
# Out:
# Text(0.5, 1.0, 'Reward Scores - MLP')

# %%
import numpy as np
from sklearn.metrics import mutual_info_score
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

from scipy.special import kl_div

# %%
import pandas as pd
import glob
from functools import reduce
import numpy as np
import matplotlib.pyplot as plt
reward_files = glob.glob('/users/lucelo/UQLRM/metadata_single_mlp_*.tsv')
reward_dfs = []
for file in reward_files:
    df = pd.read_csv(file, sep='\t', header=0)[['id', 'RewardScore', 'Dataset', 'Preference']]
    chosen_df = df[df['Preference'] == 'chosen'].rename(columns={'RewardScore': 'RewardChosen'})
    rejected_df = df[df['Preference'] == 'rejected'].rename(columns={'RewardScore': 'RewardRejected'})
    merged_df = chosen_df.merge(rejected_df, on=['id', 'Dataset'], how='inner')
    merged_df['RewardDiff'] = merged_df['RewardChosen'] - merged_df['RewardRejected']
    merged_df['PreferenceProb'] = sigmoid(merged_df['RewardDiff'])
    reward_dfs.append(merged_df)

for i, df in enumerate(reward_dfs):
    # Add unique suffixes to the column names
    df.columns = [f"{col}_{i}" if col != 'id' else col for col in df.columns]

final_rewards =  pd.concat(reward_dfs, axis=1)

# %%
reward_dfs[0].head()
# Out:
#       id  RewardChosen_0 Dataset_0 Preference_x_0  RewardRejected_0  \
# 0   1801       -1.006395     train         chosen         -1.288653
# 1  87053        1.444511     train         chosen         -0.509335
# 2  59149       -0.103756     train         chosen         -0.680847
# 3  20080        1.246241     train         chosen         -2.328310
# 4  72323        0.469603     train         chosen         -0.206598
#
#   Preference_y_0  RewardDiff_0  PreferenceProb_0
# 0       rejected      0.282258          0.570100
# 1       rejected      1.953846          0.875865
# 2       rejected      0.577090          0.640398
# 3       rejected      3.574551          0.972736
# 4       rejected      0.676201          0.662890

# %%
len(reward_dfs[0])
# Out:
# 13337

# %%
final_rewards.head()
# Out:
#       id  RewardChosen_0 Dataset_0 Preference_x_0  RewardRejected_0  \
# 0   1801       -1.006395     train         chosen         -1.288653
# 1  87053        1.444511     train         chosen         -0.509335
# 2  59149       -0.103756     train         chosen         -0.680847
# 3  20080        1.246241     train         chosen         -2.328310
# 4  72323        0.469603     train         chosen         -0.206598
#
#   Preference_y_0  RewardDiff_0  PreferenceProb_0     id  RewardChosen_1  ...  \
# 0       rejected      0.282258          0.570100   1801       -1.185594  ...
# 1       rejected      1.953846          0.875865  87053        1.526522  ...
# 2       rejected      0.577090          0.640398  59149        0.135625  ...
# 3       rejected      3.574551          0.972736  20080        1.238998  ...
# 4       rejected      0.676201          0.662890  72323        0.196873  ...
#
#   RewardDiff_35 PreferenceProb_35     id RewardChosen_36  Dataset_36  \
# ...

# %%
from tqdm import tqdm
tqdm.pandas()
N = len(reward_dfs)
pairs = [(i, j) for i in range(N) for j in range(N)]
def compute_rw_diff_pairs(x):
    # np.random.shuffle(pairs)
    # pairs = pairs[:N]
    diffs = []
    for pair in pairs:
        i,j = pair
        diffs.append(x[f'RewardChosen_{i}'] - x[f'RewardRejected_{j}'])
    return np.var(diffs)
    
final_rewards['RwDiffDistincPairs'] = final_rewards.progress_apply(lambda x: compute_rw_diff_pairs(x), axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13337/13337 [02:00<00:00, 110.31it/s]
# /scratch-ssd/lucelo/tmp/ipykernel_3922370/1458677695.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_rewards['RwDiffDistincPairs'] = final_rewards.progress_apply(lambda x: compute_rw_diff_pairs(x), axis=1)

# %%
final_rewards.head()
# Out:
#       id  RewardChosen_0 Dataset_0 Preference_x_0  RewardRejected_0  \
# 0   1801       -1.006395     train         chosen         -1.288653
# 1  87053        1.444511     train         chosen         -0.509335
# 2  59149       -0.103756     train         chosen         -0.680847
# 3  20080        1.246241     train         chosen         -2.328310
# 4  72323        0.469603     train         chosen         -0.206598
#
#   Preference_y_0  RewardDiff_0  PreferenceProb_0     id  RewardChosen_1  ...  \
# 0       rejected      0.282258          0.570100   1801       -1.185594  ...
# 1       rejected      1.953846          0.875865  87053        1.526522  ...
# 2       rejected      0.577090          0.640398  59149        0.135625  ...
# 3       rejected      3.574551          0.972736  20080        1.238998  ...
# 4       rejected      0.676201          0.662890  72323        0.196873  ...
#
#   PreferenceProb_35     id  RewardChosen_36 Dataset_36  Preference_x_36  \
# ...

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwDiffDistincPairs'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwDiffDistincPairs'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwDiffDistincPairs'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwDiffDistincPairs'].hist(bins=100, alpha=0.5, label='eval')
plt.legend()

# %%
covariances = []
for index, row in final_rewards.iterrows():
    rejected = [row[f'RewardRejected_{n}'] for n in range(len(reward_dfs))]
    chosen = [row[f'RewardChosen_{i}'] for i in range(len(reward_dfs))]
    covariance = np.cov(rejected, chosen)[0][1]
    covariances.append(covariance)

final_rewards['Covariance'] = covariances
# Out:
# /scratch-ssd/lucelo/tmp/ipykernel_3922370/3714891350.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_rewards['Covariance'] = covariances

# %%
final_rewards['RwAverage'] = final_rewards.filter(like="Reward", axis=1).mean(axis=1)
final_rewards['RwVariance'] = final_rewards.filter(like="Reward", axis=1).var(axis=1)
final_rewards['RwChosenAverage'] = final_rewards.filter(like="RewardChosen", axis=1).mean(axis=1)
final_rewards['RwChosenVariance'] = final_rewards.filter(like="RewardChosen", axis=1).var(axis=1)
final_rewards['RwRejectedAverage'] = final_rewards.filter(like="RewardRejected", axis=1).mean(axis=1)
final_rewards['RwRejectedVariance'] = final_rewards.filter(like="RewardRejected", axis=1).var(axis=1)
final_rewards['RwDiffAverage'] = final_rewards.filter(like="RewardDiff", axis=1).mean(axis=1)
final_rewards['RwDiffVariance'] = final_rewards.filter(like="RewardDiff", axis=1).var(axis=1)
final_rewards['RwVarianceSum'] = final_rewards['RwChosenVariance'] + final_rewards['RwRejectedVariance']
final_rewards['RwDiffAnalyticalVariance'] = final_rewards['RwChosenVariance'] + final_rewards['RwRejectedVariance'] - 2*final_rewards['Covariance']
final_rewards['PrefProbVariance'] = final_rewards.filter(like="PreferenceProb", axis=1).var(axis=1)
final_rewards['PrefProbAverage'] = final_rewards.filter(like="PreferenceProb", axis=1).mean(axis=1)
final_rewards['RewardMaxVariance'] = final_rewards[['RwChosenVariance', 'RwRejectedVariance']].max(axis=1)
# Out:
# /scratch-ssd/lucelo/tmp/ipykernel_3922370/1817958673.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_rewards['RewardMaxVariance'] = final_rewards[['RwChosenVariance', 'RwRejectedVariance']].max(axis=1)

# %%
final_rewards['RwChosenAverage'].hist(bins=100, alpha=0.5, legend='RewardChosenAverage')
final_rewards['RwRejectedAverage'].hist(bins=100, alpha=0.5, legend='RewardRejectedAverage')
final_rewards['RwDiffAverage'].hist(bins=100, alpha=0.5, legend='RewardDiffAverage')
final_rewards['RwAverage'].hist(bins=100, alpha=0.5, legend='RewardAverage')
# Out:
# <Axes: >

# %%
final_rewards['RwChosenVariance'].hist(bins=100, alpha=0.5, legend='RewardChosenVariance')
final_rewards['RwRejectedVariance'].hist(bins=100, alpha=0.5, legend='RewardRejectedVariance')
final_rewards['RwDiffVariance'].hist(bins=100, alpha=0.5, legend='RewardDiffVariance')
final_rewards['RwDiffAnalyticalVariance'].hist(bins=100, alpha=0.5, legend='RewardDiffAnalyticalVariance')
# final_rewards['RwVariance'].hist(bins=100, alpha=0.5, legend='RewardVariance')
# Out:
# <Axes: >

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='eval')
plt.legend()

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='eval')
# Out:
# <Axes: >

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='eval')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='ood')
plt.legend()

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RewardMaxVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RewardMaxVariance'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RewardMaxVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RewardMaxVariance'].hist(bins=100, alpha=0.5, label='eval')
plt.legend()

# %%
# final_rewards[final_rewards['Dataset_0'] == 'train']['RwDiffAnalyticalVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwDiffAnalyticalVariance'].hist(bins=100, alpha=0.5, label='ood_ana')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='ood')
#final_rewards[final_rewards['Dataset_0'] == 'test']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='test')
#final_rewards[final_rewards['Dataset_0'] == 'eval']['RwRejectedVariance'].hist(bins=100, alpha=0.5, label='eval')
plt.legend()

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwVarianceSum'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwVarianceSum'].hist(bins=100, alpha=0.5, label='ood')
#final_rewards[final_rewards['Dataset_0'] == 'test']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='test')
#final_rewards[final_rewards['Dataset_0'] == 'eval']['RwDiffVariance'].hist(bins=100, alpha=0.5, label='eval')
# Out:
# <Axes: >

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['MaxVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwChosenVariance'].hist(bins=100, alpha=0.5, label='eval')
plt.legend()

# %%
final_rewards[final_rewards['Dataset_0'] == 'train']['RwVariance'].hist(bins=100, alpha=0.5, label='train')
final_rewards[final_rewards['Dataset_0'] == 'ood']['RwVariance'].hist(bins=100, alpha=0.5, label='ood')
final_rewards[final_rewards['Dataset_0'] == 'test']['RwVariance'].hist(bins=100, alpha=0.5, label='test')
final_rewards[final_rewards['Dataset_0'] == 'eval']['RwVariance'].hist(bins=100, alpha=0.5, label='eval')
plt.show()

# %%
final_rewards.head(10)
# Out:
#       id  RewardChosen_0 Dataset_0 Preference_x_0  RewardRejected_0  \
# 0   1801       -1.006395     train         chosen         -1.288653
# 1  87053        1.444511     train         chosen         -0.509335
# 2  59149       -0.103756     train         chosen         -0.680847
# 3  20080        1.246241     train         chosen         -2.328310
# 4  72323        0.469603     train         chosen         -0.206598
# 5  41764       -0.730370     train         chosen         -0.792922
# 6  23570       -2.358257     train         chosen          1.014640
# 7  71199       -0.695544     train         chosen         -1.723392
# 8   9979       -0.291035     train         chosen         -0.360346
# 9  83110        2.211254     train         chosen          1.593001
#
#   Preference_y_0  RewardDiff_0  PreferenceProb_0     id  RewardChosen_1  \
# 0       rejected      0.282258          0.570100   1801       -1.185594
# 1       rejected      1.953846          0.875865  87053        1.526522
# ...

# %%
pd.options.display.max_columns=100
final_rewards.iloc[6]
# Out:
# id                             23570
# RewardChosen_0             -2.358257
# Dataset_0                      train
# Preference_x_0                chosen
# RewardRejected_0             1.01464
#                               ...
# RwDiffVariance              0.041875
# RwVarianceSum               0.058005
# RwDiffAnalyticalVariance    0.041875
# PrefProbVariance            0.000071
# PrefProbAverage             0.039407
# Name: 6, Length: 310, dtype: object

# %%
train_df = final_rewards[final_rewards['Dataset_0'] == 'train'][['RwDiffAverage', 'RwDiffVariance', 'RwVarianceSum', 'PrefProbVariance', 'PrefProbAverage', 'RwDiffDistincPairs', 'RewardMaxVariance', 'RwRejectedAverage', 'RwChosenAverage']]

# %%
train_df['Error'] = (train_df['RwDiffAverage'] < 0) * 1.0
train_df['Prob'] = sigmoid(train_df['RwDiffAverage'])
train_df['GT'] = 1.0
train_df['Error'] = (train_df['RwDiffAverage'] < 0) * 1.0
train_df['CrossEntropy'] = kl_div(train_df['GT'], train_df['Prob'])
chosen_p5 = train_df['RwChosenAverage'].quantile(0.01)
chosen_p95 = train_df['RwChosenAverage'].quantile(0.99)
rej_p5 = train_df['RwRejectedAverage'].quantile(0.01)
rej_p95 = train_df['RwRejectedAverage'].quantile(0.99)

print(chosen_p5,chosen_p95)
print(rej_p5,rej_p95)
train_df['TooHighOrTooLow'] = (train_df['RwChosenAverage'] > chosen_p95) | (train_df['RwChosenAverage'] < chosen_p5) | (train_df['RwRejectedAverage'] < rej_p5) | (train_df['RwRejectedAverage'] > rej_p95)
# Out:
# -2.382606646176931 2.2696335054732684
# -2.8118437999003643 2.0057470606791026

# %%
train_df.head(100)
# Out:
#     RwDiffAverage  RwDiffVariance  RwVarianceSum  PrefProbVariance  \
# 0        0.258358        0.029472       0.043538          0.001764
# 1        1.824558        0.019963       0.043035          0.000287
# 2        0.619781        0.018803       0.042641          0.000972
# 3        3.219694        0.030637       0.034972          0.000046
# 4        0.502953        0.036019       0.053163          0.001990
# ..            ...             ...            ...               ...
# 95       0.708011        0.011967       0.037681          0.000583
# 96       2.399315        0.055339       0.074056          0.000350
# 97       3.100848        0.018564       0.034168          0.000033
# 98       0.413864        0.020926       0.051396          0.001177
# 99      -0.924719        0.028563       0.049089          0.001141
#
#     PrefProbAverage  RwDiffDistincPairs  RewardMaxVariance  RwRejectedAverage  \
# 0          0.563791            0.042361           0.024925          -1.205989
# ...

# %%
train_df[train_df['Error'] == 1.0]
# Out:
#       RwDiffAverage  RwDiffVariance  RwVarianceSum  PrefProbVariance  \
# 5         -0.274539        0.046086       0.057242          0.002730
# 6         -3.213233        0.041875       0.058005          0.000071
# 13        -0.012412        0.044522       0.063088          0.002739
# 14        -0.353285        0.009980       0.041920          0.000581
# 17        -0.031382        0.007750       0.022777          0.000483
# ...             ...             ...            ...               ...
# 2764      -0.121881        0.008943       0.069284          0.000550
# 2766      -0.305461        0.056657       0.062078          0.003342
# 2767      -1.237039        0.040379       0.044904          0.001168
# 2780      -0.268621        0.030055       0.045648          0.001803
# 2783      -1.114180        0.053094       0.076642          0.001817
#
#       PrefProbAverage  RwDiffDistincPairs  RewardMaxVariance  \
# 5            0.432549            0.055695           0.029177
# ...

# %%
print(f"Correlation Between Var(r1) + Var(r2) and Cross Entropy for Training: {train_df['RwVarianceSum'].corr(train_df['CrossEntropy'])}")
print(f"Correlation Between Var(r1-r2) and Cross Entropy for Training: {train_df['RwDiffVariance'].corr(train_df['CrossEntropy'])}")
print(f"Correlation Between Var(p) and Cross Entropy for Training: {train_df['PrefProbVariance'].corr(train_df['CrossEntropy'])}")
print(f"Correlation Between Var(r1-r2, *) and Cross Entropy for Training: {train_df['RwDiffDistincPairs'].corr(train_df['CrossEntropy'])}")
print(f"Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: {train_df['RewardMaxVariance'].corr(train_df['CrossEntropy'])}")
print(f"Correlation Between TooHighTooLow and Cross Entropy for Training: {train_df['TooHighOrTooLow'].corr(train_df['CrossEntropy'])}")
# Out:
# Correlation Between Var(r1) + Var(r2) and Cross Entropy for Training: 0.003341653422885114
# Correlation Between Var(r1-r2) and Cross Entropy for Training: 0.00858900266206685
# Correlation Between Var(p) and Cross Entropy for Training: 0.06972643834090708
# Correlation Between Var(r1-r2, *) and Cross Entropy for Training: 0.0033416534228850963
# Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: 0.0061815359273219
# Correlation Between TooHighTooLow and Cross Entropy for Training: 0.13682433120630136

# %%
from scipy import stats
print(f"Correlation Between Var(r1) + Var(r2) and Cross Entropy for Training: {stats.spearmanr(train_df['RwVarianceSum'], train_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(r1-r2) and Cross Entropy for Training: {stats.spearmanr(train_df['RwDiffVariance'], train_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(p) and Cross Entropy for Training: {stats.spearmanr(train_df['PrefProbVariance'], train_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(r1-r2, *) and Cross Entropy for Training: {stats.spearmanr(train_df['RwDiffDistincPairs'], train_df['CrossEntropy'])[0]}")
print(f"Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: {stats.spearmanr(train_df['RewardMaxVariance'], train_df['CrossEntropy'])[0]}")
print(f"Correlation Between TooHighTooLow and Cross Entropy for Training: {stats.spearmanr(train_df['TooHighOrTooLow'], train_df['CrossEntropy'])[0]}")
# Out:
# Correlation Between Var(r1) + Var(r2) and Cross Entropy for Training: 0.04065761719632698
# Correlation Between Var(r1-r2) and Cross Entropy for Training: -0.09428686490668754
# Correlation Between Var(p) and Cross Entropy for Training: 0.4838109566728942
# Correlation Between Var(r1-r2, *) and Cross Entropy for Training: 0.04065697234545108
# Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: -0.015007644099122839
# Correlation Between TooHighTooLow and Cross Entropy for Training: 0.04111634551705905

# %%
ood_df = final_rewards[final_rewards['Dataset_0'] == 'ood'][['RwDiffAverage', 'RwDiffVariance', 'RwVarianceSum', 'PrefProbVariance', 'RwDiffDistincPairs', 'RewardMaxVariance', 'RwRejectedAverage', 'RwChosenAverage']]
ood_df['Prob'] = sigmoid(ood_df['RwDiffAverage'])
ood_df['GT'] = 1.0
ood_df['Error'] = (ood_df['RwDiffAverage'] < 0) * 1.0
ood_df['CrossEntropy'] = kl_div(ood_df['GT'], ood_df['Prob'])
ood_df.head()

chosen_p5 = ood_df['RwChosenAverage'].quantile(0.05)
chosen_p95 = ood_df['RwChosenAverage'].quantile(0.95)
rej_p5 = ood_df['RwRejectedAverage'].quantile(0.05)
rej_p95 = ood_df['RwRejectedAverage'].quantile(0.95)

print(chosen_p5,chosen_p95)
print(rej_p5,rej_p95)
ood_df['TooHighOrTooLow'] = (ood_df['RwChosenAverage'] > chosen_p95) | (ood_df['RwChosenAverage'] < chosen_p5) | (ood_df['RwRejectedAverage'] < rej_p5) | (ood_df['RwRejectedAverage'] > rej_p95)
# Out:
# -1.7173503121814213 1.32952963129894
# -2.0486140226995624 0.9683011228168323

# %%
print(f"Correlation Between Var(r1) + Var(r2) and Cross Entropy for OOD: {ood_df['RwVarianceSum'].corr(ood_df['CrossEntropy'])}")
print(f"Correlation Between Var(r1-r2) and Cross Entropy for OOD: {ood_df['RwDiffVariance'].corr(ood_df['CrossEntropy'])}")
print(f"Correlation Between Var(p) and Cross Entropy for OOD: {ood_df['PrefProbVariance'].corr(ood_df['CrossEntropy'])}")
print(f"Correlation Between Var(r1-r2, *) and Cross Entropy for OOD: {ood_df['RwDiffDistincPairs'].corr(ood_df['CrossEntropy'])}")
print(f"Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: {ood_df['RewardMaxVariance'].corr(ood_df['CrossEntropy'])}")
print(f"Correlation Between TooHighTooLow and Cross Entropy for Training: {ood_df['TooHighOrTooLow'].corr(ood_df['CrossEntropy'])}")
# Out:
# Correlation Between Var(r1) + Var(r2) and Cross Entropy for OOD: 0.03327086248085485
# Correlation Between Var(r1-r2) and Cross Entropy for OOD: 0.1596922632645606
# Correlation Between Var(p) and Cross Entropy for OOD: 0.05796413595122339
# Correlation Between Var(r1-r2, *) and Cross Entropy for OOD: 0.03327086248085481
# Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for Training: 0.09488575893887381
# Correlation Between TooHighTooLow and Cross Entropy for Training: 0.10924201627540066

# %%
from scipy import stats
print(f"Correlation Between Var(r1) + Var(r2) and Cross Entropy for OOD: {stats.spearmanr(ood_df['RwVarianceSum'], ood_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(r1-r2) and Cross Entropy for OOD: {stats.spearmanr(ood_df['RwDiffVariance'], ood_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(p) and Cross Entropy for OOD: {stats.spearmanr(ood_df['PrefProbVariance'], ood_df['CrossEntropy'])[0]}")
print(f"Correlation Between Var(r1-r2, *) and Cross Entropy for OOD: {stats.spearmanr(ood_df['RwDiffDistincPairs'], ood_df['CrossEntropy'])[0]}")
print(f"Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for OOD: {stats.spearmanr(ood_df['RewardMaxVariance'], ood_df['CrossEntropy'])[0]}")
print(f"Correlation Between TooHighTooLow and Cross Entropy for Training: {stats.spearmanr(ood_df['TooHighOrTooLow'], ood_df['CrossEntropy'])[0]}")
# Out:
# Correlation Between Var(r1) + Var(r2) and Cross Entropy for OOD: 0.13792352431083343
# Correlation Between Var(r1-r2) and Cross Entropy for OOD: -0.03184084409866624
# Correlation Between Var(p) and Cross Entropy for OOD: 0.22281043380597387
# Correlation Between Var(r1-r2, *) and Cross Entropy for OOD: 0.13791803033778047
# Correlation Between max(Var(r1), Var(r2)) and Cross Entropy for OOD: 0.10728511410914536
# Correlation Between TooHighTooLow and Cross Entropy for Training: -0.01985003856796197

# %%
train_df.sort_values(by='PrefProbVariance', ascending=False, inplace=True)

# %%
plt.yscale('linear')
y = train_df['CrossEntropy'].values
plt.scatter(y =y, x = range(len(y)))

# %%
final_rewards[final_rewards['Dataset_0'] == 'test'].head(10)
# Out:
#          id  RewardChosen_0 Dataset_0 Preference_x_0  RewardRejected_0  \
# 6095   1667        1.756641      test         chosen          1.247128
# 6096  26020        0.391351      test         chosen         -0.032833
# 6097   5937       -0.801907      test         chosen         -0.973762
# 6098  23105        1.002969      test         chosen         -1.808711
# 6099    319        1.215330      test         chosen          1.121460
# 6100   6357       -0.462155      test         chosen         -0.025432
# 6101   7324        0.361908      test         chosen          0.188909
# 6102    725        0.194986      test         chosen         -1.062474
# 6103  29835        2.539452      test         chosen          1.490417
# 6104  45878        1.486320      test         chosen          1.214428
#
#      Preference_y_0  RewardDiff_0  PreferenceProb_0     id  RewardChosen_1  \
# 6095       rejected      0.509513          0.624692   1667        1.537055
# ...
